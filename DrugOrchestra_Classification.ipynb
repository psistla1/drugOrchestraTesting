# %%
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Directory containing the data files
data_directory = 'D:\\data\\PCA_data\\classification' #insert data file here
data_files = [f for f in os.listdir(data_directory) if f.endswith('.npy')]

# Initialize classifiers
models = {
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'Logistic Regression': LogisticRegression(),
    'Naive Bayes': GaussianNB(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(n_estimators=100),
    'SVM': SVC(),
    'Gradient Boosting': GradientBoostingClassifier(n_estimators=100),
    'MLP Neural Network': MLPClassifier(hidden_layer_sizes=(100,), max_iter=300)
}

# %%
# Process each file
for file_name in data_files:
    file_path = os.path.join(data_directory, file_name)
    print(f"Processing {file_name}")
    
    data = np.load(file_path)
    X = data[:, :-1]
    y = data[:, -1]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

    for name, model in models.items():
        model.fit(X_train, y_train)
        predictions_proba = model.predict_proba(X_test)[:,1]
        auc_score = roc_auc_score(y_test, predictions_proba)
        auprc_score = average_precision_score(y_test, predictions_proba)
        
        # Using cross-validation to estimate margin of error
        cv_auc = cross_val_score(model, X, y, cv=5, scoring='roc_auc')
        cv_auprc = cross_val_score(model, X, y, cv=5, scoring='average_precision')

        print(f"{name} AUROC: {auc_score} ± {cv_auc.std()}")
        print(f"{name} AUPRC: {auprc_score} ± {cv_auprc.std()}")
# Out:
# Processing db_data_pca.npy
# KNN Accuracy: 0.9118023280603761
# KNN Confusion Matrix:
# [[83850  1382]
#  [ 6892  1688]]
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.92      0.98      0.95     85232
#          1.0       0.55      0.20      0.29      8580
#
#     accuracy                           0.91     93812
#    macro avg       0.74      0.59      0.62     93812
# weighted avg       0.89      0.91      0.89     93812
#
# Logistic Regression Accuracy: 0.9192427408007504
# Logistic Regression Confusion Matrix:
# [[84687   545]
#  [ 7031  1549]]
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.92      0.99      0.96     85232
#          1.0       0.74      0.18      0.29      8580
#
#     accuracy                           0.92     93812
#    macro avg       0.83      0.59      0.62     93812
# weighted avg       0.91      0.92      0.90     93812
#
# Naive Bayes Accuracy: 0.854240395684987
# Naive Bayes Confusion Matrix:
# [[76645  8587]
#  [ 5087  3493]]
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.94      0.90      0.92     85232
#          1.0       0.29      0.41      0.34      8580
#
#     accuracy                           0.85     93812
#    macro avg       0.61      0.65      0.63     93812
# weighted avg       0.88      0.85      0.87     93812
#
# Decision Tree Accuracy: 0.9204899160022172
# Decision Tree Confusion Matrix:
# [[84610   622]
#  [ 6837  1743]]
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.93      0.99      0.96     85232
#          1.0       0.74      0.20      0.32      8580
#
#     accuracy                           0.92     93812
#    macro avg       0.83      0.60      0.64     93812
# weighted avg       0.91      0.92      0.90     93812
#
# Random Forest Accuracy: 0.9207777256640941
# Random Forest Confusion Matrix:
# [[84614   618]
#  [ 6814  1766]]
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.93      0.99      0.96     85232
#          1.0       0.74      0.21      0.32      8580
#
#     accuracy                           0.92     93812
#    macro avg       0.83      0.60      0.64     93812
# weighted avg       0.91      0.92      0.90     93812
#
# Gradient Boosting Accuracy: 0.9203406813627254
# Gradient Boosting Confusion Matrix:
# [[84742   490]
#  [ 6983  1597]]
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.92      0.99      0.96     85232
#          1.0       0.77      0.19      0.30      8580
#
#     accuracy                           0.92     93812
#    macro avg       0.84      0.59      0.63     93812
# weighted avg       0.91      0.92      0.90     93812
#
# MLP Neural Network Accuracy: 0.9199782543811026
# MLP Neural Network Confusion Matrix:
# [[84890   342]
#  [ 7165  1415]]
# MLP Neural Network Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.92      1.00      0.96     85232
#          1.0       0.81      0.16      0.27      8580
#
#     accuracy                           0.92     93812
#    macro avg       0.86      0.58      0.62     93812
# weighted avg       0.91      0.92      0.90     93812
#
# Processing rh_data_pca.npy
# KNN Accuracy: 0.9079913246579914
# KNN Confusion Matrix:
# [[43250   272]
#  [ 4140   290]]
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      0.99      0.95     43522
#          1.0       0.52      0.07      0.12      4430
#
#     accuracy                           0.91     47952
#    macro avg       0.71      0.53      0.53     47952
# weighted avg       0.88      0.91      0.87     47952
#
# Logistic Regression Accuracy: 0.9079287620954287
# Logistic Regression Confusion Matrix:
# [[43469    53]
#  [ 4362    68]]
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      1.00      0.95     43522
#          1.0       0.56      0.02      0.03      4430
#
#     accuracy                           0.91     47952
#    macro avg       0.74      0.51      0.49     47952
# weighted avg       0.88      0.91      0.87     47952
#
# Naive Bayes Accuracy: 0.7414080747414081
# Naive Bayes Confusion Matrix:
# [[33677  9845]
#  [ 2555  1875]]
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.93      0.77      0.84     43522
#          1.0       0.16      0.42      0.23      4430
#
#     accuracy                           0.74     47952
#    macro avg       0.54      0.60      0.54     47952
# weighted avg       0.86      0.74      0.79     47952
#
# Decision Tree Accuracy: 0.9095345345345346
# Decision Tree Confusion Matrix:
# [[43358   164]
#  [ 4174   256]]
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      1.00      0.95     43522
#          1.0       0.61      0.06      0.11      4430
#
#     accuracy                           0.91     47952
#    macro avg       0.76      0.53      0.53     47952
# weighted avg       0.88      0.91      0.87     47952
#
# Random Forest Accuracy: 0.9098056389723056
# Random Forest Confusion Matrix:
# [[43356   166]
#  [ 4159   271]]
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      1.00      0.95     43522
#          1.0       0.62      0.06      0.11      4430
#
#     accuracy                           0.91     47952
#    macro avg       0.77      0.53      0.53     47952
# weighted avg       0.89      0.91      0.87     47952
#
# Gradient Boosting Accuracy: 0.9098890557223891
# Gradient Boosting Confusion Matrix:
# [[43435    87]
#  [ 4234   196]]
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      1.00      0.95     43522
#          1.0       0.69      0.04      0.08      4430
#
#     accuracy                           0.91     47952
#    macro avg       0.80      0.52      0.52     47952
# weighted avg       0.89      0.91      0.87     47952
#
# MLP Neural Network Accuracy: 0.9104312645979312
# MLP Neural Network Confusion Matrix:
# [[43409   113]
#  [ 4182   248]]
# MLP Neural Network Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      1.00      0.95     43522
#          1.0       0.69      0.06      0.10      4430
#
#     accuracy                           0.91     47952
#    macro avg       0.80      0.53      0.53     47952
# weighted avg       0.89      0.91      0.87     47952
#
# Processing sider_data_pca.npy
# KNN Accuracy: 0.8883229627456171
# KNN Confusion Matrix:
# [[267432   6979]
#  [ 28037  11099]]
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      0.97      0.94    274411
#          1.0       0.61      0.28      0.39     39136
#
#     accuracy                           0.89    313547
#    macro avg       0.76      0.63      0.66    313547
# weighted avg       0.87      0.89      0.87    313547
#
# Logistic Regression Accuracy: 0.8844224310868865
# Logistic Regression Confusion Matrix:
# [[273510    901]
#  [ 35338   3798]]
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.89      1.00      0.94    274411
#          1.0       0.81      0.10      0.17     39136
#
#     accuracy                           0.88    313547
#    macro avg       0.85      0.55      0.56    313547
# weighted avg       0.88      0.88      0.84    313547
#
# Naive Bayes Accuracy: 0.85528485362641
# Naive Bayes Confusion Matrix:
# [[253852  20559]
#  [ 24816  14320]]
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      0.93      0.92    274411
#          1.0       0.41      0.37      0.39     39136
#
#     accuracy                           0.86    313547
#    macro avg       0.66      0.65      0.65    313547
# weighted avg       0.85      0.86      0.85    313547
#
# Decision Tree Accuracy: 0.8954957311025141
# Decision Tree Confusion Matrix:
# [[269206   5205]
#  [ 27562  11574]]
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      0.98      0.94    274411
#          1.0       0.69      0.30      0.41     39136
#
#     accuracy                           0.90    313547
#    macro avg       0.80      0.64      0.68    313547
# weighted avg       0.88      0.90      0.88    313547
#
# Random Forest Accuracy: 0.895505299046076
# Random Forest Confusion Matrix:
# [[269254   5157]
#  [ 27607  11529]]
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      0.98      0.94    274411
#          1.0       0.69      0.29      0.41     39136
#
#     accuracy                           0.90    313547
#    macro avg       0.80      0.64      0.68    313547
# weighted avg       0.88      0.90      0.88    313547
#
# Gradient Boosting Accuracy: 0.8924722609369569
# Gradient Boosting Confusion Matrix:
# [[270646   3765]
#  [ 29950   9186]]
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.90      0.99      0.94    274411
#          1.0       0.71      0.23      0.35     39136
#
#     accuracy                           0.89    313547
#    macro avg       0.80      0.61      0.65    313547
# weighted avg       0.88      0.89      0.87    313547
#
# MLP Neural Network Accuracy: 0.8942104373507002
# MLP Neural Network Confusion Matrix:
# [[268405   6006]
#  [ 27164  11972]]
# MLP Neural Network Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.91      0.98      0.94    274411
#          1.0       0.67      0.31      0.42     39136
#
#     accuracy                           0.89    313547
#    macro avg       0.79      0.64      0.68    313547
# weighted avg       0.88      0.89      0.88    313547
#
# Processing sos_data_pca.npy
# KNN Accuracy: 0.7609965107660044
# KNN Confusion Matrix:
# [[217996  20331]
#  [ 58989  34562]]
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.79      0.91      0.85    238327
#          1.0       0.63      0.37      0.47     93551
#
#     accuracy                           0.76    331878
#    macro avg       0.71      0.64      0.66    331878
# weighted avg       0.74      0.76      0.74    331878
#
# Logistic Regression Accuracy: 0.7425318942502968
# Logistic Regression Confusion Matrix:
# [[236875   1452]
#  [ 83996   9555]]
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.74      0.99      0.85    238327
#          1.0       0.87      0.10      0.18     93551
#
#     accuracy                           0.74    331878
#    macro avg       0.80      0.55      0.51    331878
# weighted avg       0.77      0.74      0.66    331878
#
# Naive Bayes Accuracy: 0.7042015439408458
# Naive Bayes Confusion Matrix:
# [[202470  35857]
#  [ 62312  31239]]
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.76      0.85      0.80    238327
#          1.0       0.47      0.33      0.39     93551
#
#     accuracy                           0.70    331878
#    macro avg       0.62      0.59      0.60    331878
# weighted avg       0.68      0.70      0.69    331878
#
# Decision Tree Accuracy: 0.7799221400635173
# Decision Tree Confusion Matrix:
# [[224547  13780]
#  [ 59259  34292]]
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.79      0.94      0.86    238327
#          1.0       0.71      0.37      0.48     93551
#
#     accuracy                           0.78    331878
#    macro avg       0.75      0.65      0.67    331878
# weighted avg       0.77      0.78      0.75    331878
#
# Random Forest Accuracy: 0.7798889953537144
# Random Forest Confusion Matrix:
# [[224195  14132]
#  [ 58918  34633]]
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.79      0.94      0.86    238327
#          1.0       0.71      0.37      0.49     93551
#
#     accuracy                           0.78    331878
#    macro avg       0.75      0.66      0.67    331878
# weighted avg       0.77      0.78      0.75    331878
#
# Gradient Boosting Accuracy: 0.7645279289377421
# Gradient Boosting Confusion Matrix:
# [[232933   5394]
#  [ 72754  20797]]
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.76      0.98      0.86    238327
#          1.0       0.79      0.22      0.35     93551
#
#     accuracy                           0.76    331878
#    macro avg       0.78      0.60      0.60    331878
# weighted avg       0.77      0.76      0.71    331878
#
# MLP Neural Network Accuracy: 0.7784456938995655
# MLP Neural Network Confusion Matrix:
# [[227922  10405]
#  [ 63124  30427]]
# MLP Neural Network Classification Report:
#               precision    recall  f1-score   support
#
#         -1.0       0.78      0.96      0.86    238327
#          1.0       0.75      0.33      0.45     93551
#
#     accuracy                           0.78    331878
#    macro avg       0.76      0.64      0.66    331878
# weighted avg       0.77      0.78      0.75    331878
#
# Processing stitch_data_900_pca.npy
